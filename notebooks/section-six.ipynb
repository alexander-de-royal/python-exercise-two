# %%
import pandas as pd

# %%
houses = pd.read_csv("../../colt-data/data/kc_house_data.csv")

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
houses.min()
# Out:
# id                       1000102
# date             20140502T000000
# price                    75000.0
# bedrooms                       0
# bathrooms                    0.0
# sqft_living                  290
# sqft_lot                     520
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      1
# grade                          1
# sqft_above                   290
# sqft_basement                  0
# yr_built                    1900
# yr_renovated                   0
# zipcode                    98001
# lat                      47.1559
# long                    -122.519
# sqft_living15                399
# sqft_lot15                   651
# dtype: object

# %%
houses.max()
# Out:
# id                    9900000190
# date             20150527T000000
# price                  7700000.0
# bedrooms                      33
# bathrooms                    8.0
# sqft_living                13540
# sqft_lot                 1651359
# floors                       3.5
# waterfront                     1
# view                           4
# condition                      5
# grade                         13
# sqft_above                  9410
# sqft_basement               4820
# yr_built                    2015
# yr_renovated                2015
# zipcode                    98199
# lat                      47.7776
# long                    -121.315
# sqft_living15               6210
# sqft_lot15                871200
# dtype: object

# %%
type(houses.max())
# Out:
# pandas.core.series.Series

# %%
houses.sum()
# Out:
# id                                                  98994056770455
# date             20141013T00000020141209T00000020150225T0000002...
# price                                                11672925008.0
# bedrooms                                                     72854
# bathrooms                                                 45706.25
# sqft_living                                               44952873
# sqft_lot                                                 326506890
# floors                                                     32296.5
# waterfront                                                     163
# view                                                          5064
# condition                                                    73688
# grade                                                       165488
# sqft_above                                                38652488
# sqft_basement                                              6300385
# ...

# %%
titanic = pd.read_csv("../../colt-data/data/titanic.csv")

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.sum()
# Out:
# pclass                                                    3004
# survived                                                   500
# name         Allen, Miss. Elisabeth WaltonAllison, Master. ...
# sex          femalemalefemalemalefemalemalefemalemalefemale...
# age          290.91672302548633953714718242680?245032363747...
# sibsp                                                      653
# parch                                                      504
# ticket       2416011378111378111378111378119952135021120501...
# fare         211.3375151.55151.55151.55151.5526.5577.958305...
# cabin        B5C22 C26C22 C26C22 C26C22 C26E12D7A36C101?C62...
# embarked     SSSSSSSSSCCCCSSSCCCCSSCCSCCCSSSCSSSCSSSCCCSCCS...
# boat         211???310?D??496B??68A55548?778D?788?469???6D8...
# body         ???135?????22124??????????????148?????????????...
# home.dest    St Louis, MOMontreal, PQ / Chesterville, ONMon...
# dtype: object

# %%
titanic.count()
# Out:
# pclass       1309
# survived     1309
# name         1309
# sex          1309
# age          1309
# sibsp        1309
# parch        1309
# ticket       1309
# fare         1309
# cabin        1309
# embarked     1309
# boat         1309
# body         1309
# home.dest    1309
# dtype: int64

# %%
titanic.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 titanic.mean()
#
# File ~/PycharmProjects/pythonProject/venv/lib/python3.9/site-packages/pandas/core/frame.py:11700, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11692 @doc(make_doc("mean", ndim=2))
#   11693 def mean(
#   11694     self,
#    (...)
#   11698     **kwargs,
#   11699 ):
# > 11700     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11701     if isinstance(result, Series):
#   11702         result = result.__finalize__(self, method="mean")
#
# File ~/PycharmProjects/pythonProject/venv/lib/python3.9/site-packages/pandas/core/generic.py:12439, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12432 def mean(
#   12433     self,
#   12434     axis: Axis | None = 0,
#    (...)
#   12437     **kwargs,
#   12438 ) -> Series | float:
# ...

# %%
houses.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 houses.mean()
#
# File ~/PycharmProjects/pythonProject/venv/lib/python3.9/site-packages/pandas/core/frame.py:11700, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11692 @doc(make_doc("mean", ndim=2))
#   11693 def mean(
#   11694     self,
#    (...)
#   11698     **kwargs,
#   11699 ):
# > 11700     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11701     if isinstance(result, Series):
#   11702         result = result.__finalize__(self, method="mean")
#
# File ~/PycharmProjects/pythonProject/venv/lib/python3.9/site-packages/pandas/core/generic.py:12439, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12432 def mean(
#   12433     self,
#   12434     axis: Axis | None = 0,
#    (...)
#   12437     **kwargs,
#   12438 ) -> Series | float:
# ...

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 143.3+ KB

# %%
titanic.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 titanic.mean()
#
# File ~/PycharmProjects/pythonProject/venv/lib/python3.9/site-packages/pandas/core/frame.py:11700, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11692 @doc(make_doc("mean", ndim=2))
#   11693 def mean(
#   11694     self,
#    (...)
#   11698     **kwargs,
#   11699 ):
# > 11700     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11701     if isinstance(result, Series):
#   11702         result = result.__finalize__(self, method="mean")
#
# File ~/PycharmProjects/pythonProject/venv/lib/python3.9/site-packages/pandas/core/generic.py:12439, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12432 def mean(
#   12433     self,
#   12434     axis: Axis | None = 0,
#    (...)
#   12437     **kwargs,
#   12438 ) -> Series | float:
# ...

# %%
titanic.median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 titanic.median()
#
# File ~/PycharmProjects/pythonProject/venv/lib/python3.9/site-packages/pandas/core/frame.py:11713, in DataFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   11705 @doc(make_doc("median", ndim=2))
#   11706 def median(
#   11707     self,
#    (...)
#   11711     **kwargs,
#   11712 ):
# > 11713     result = super().median(axis, skipna, numeric_only, **kwargs)
#   11714     if isinstance(result, Series):
#   11715         result = result.__finalize__(self, method="median")
#
# File ~/PycharmProjects/pythonProject/venv/lib/python3.9/site-packages/pandas/core/generic.py:12450, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   12443 def median(
#   12444     self,
#   12445     axis: Axis | None = 0,
#    (...)
#   12448     **kwargs,
# ...

# %%
titanic.max()
# Out:
# pclass                                 3
# survived                               1
# name         van Melkebeke, Mr. Philemon
# sex                                 male
# age                                    ?
# sibsp                                  8
# parch                                  9
# ticket                         WE/P 5735
# fare                                   ?
# cabin                                  T
# embarked                               S
# boat                                   D
# body                                   ?
# home.dest            Zurich, Switzerland
# dtype: object

# %%
titanic.mode()
# Out:
#    pclass  survived                  name   sex  age  sibsp  parch    ticket  \
# 0     3.0       0.0  Connolly, Miss. Kate  male    ?    0.0    0.0  CA. 2343
# 1     NaN       NaN      Kelly, Mr. James   NaN  NaN    NaN    NaN       NaN
#
#    fare cabin embarked boat body home.dest
# 0  8.05     ?        S    ?    ?         ?
# 1   NaN   NaN      NaN  NaN  NaN       NaN

# %%
titanic.describe()
# Out:
#             pclass     survived        sibsp        parch
# count  1309.000000  1309.000000  1309.000000  1309.000000
# mean      2.294882     0.381971     0.498854     0.385027
# std       0.837836     0.486055     1.041658     0.865560
# min       1.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.000000     0.000000     0.000000
# 50%       3.000000     0.000000     0.000000     0.000000
# 75%       3.000000     1.000000     1.000000     0.000000
# max       3.000000     1.000000     8.000000     9.000000

# %%
titanic.describe(include=["object"])
# Out:
#             pclass     survived        sibsp        parch
# count  1309.000000  1309.000000  1309.000000  1309.000000
# mean      2.294882     0.381971     0.498854     0.385027
# std       0.837836     0.486055     1.041658     0.865560
# min       1.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.000000     0.000000     0.000000
# 50%       3.000000     0.000000     0.000000     0.000000
# 75%       3.000000     1.000000     1.000000     0.000000
# max       3.000000     1.000000     8.000000     9.000000

# %%
bestsellers = pd.read_csv("../../colt-data/data/bestsellers.csv")

# %%
bestsellers.min()
# Out:
# Name           10-Day Green Smoothie Cleanse
# Author                      Abraham Verghese
# User Rating                              3.3
# Reviews                                   37
# Price                                      0
# Year                                    2009
# Genre                                Fiction
# dtype: object

# %%
bestsellers.max()
# Out:
# Name           You Are a Badass: How to Stop Doubting Your Gr...
# Author                                              Zhi Gang Sha
# User Rating                                                  4.9
# Reviews                                                    87841
# Price                                                        105
# Year                                                        2019
# Genre                                                Non Fiction
# dtype: object

# %%
bestsellers.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 bestsellers.mean()
#
# File ~/PycharmProjects/pythonProject/venv/lib/python3.9/site-packages/pandas/core/frame.py:11700, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11692 @doc(make_doc("mean", ndim=2))
#   11693 def mean(
#   11694     self,
#    (...)
#   11698     **kwargs,
#   11699 ):
# > 11700     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11701     if isinstance(result, Series):
#   11702         result = result.__finalize__(self, method="mean")
#
# File ~/PycharmProjects/pythonProject/venv/lib/python3.9/site-packages/pandas/core/generic.py:12439, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12432 def mean(
#   12433     self,
#   12434     axis: Axis | None = 0,
#    (...)
#   12437     **kwargs,
#   12438 ) -> Series | float:
# ...

# %%
bestsellers.head().mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 bestsellers.head().mean()
#
# File ~/PycharmProjects/pythonProject/venv/lib/python3.9/site-packages/pandas/core/frame.py:11700, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11692 @doc(make_doc("mean", ndim=2))
#   11693 def mean(
#   11694     self,
#    (...)
#   11698     **kwargs,
#   11699 ):
# > 11700     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11701     if isinstance(result, Series):
#   11702         result = result.__finalize__(self, method="mean")
#
# File ~/PycharmProjects/pythonProject/venv/lib/python3.9/site-packages/pandas/core/generic.py:12439, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12432 def mean(
#   12433     self,
#   12434     axis: Axis | None = 0,
#    (...)
#   12437     **kwargs,
# ...

# %%
import statistics as stats

# %%
import numpy as np

# %%
pip install scipy
# Out:
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
bestsellers.head().mean(numeric_only=True)
# Out:
# User Rating        4.7
# Reviews        13494.0
# Price             12.6
# Year            2016.2
# dtype: float64

# %%
bestsellers.sum()
# Out:
# Name           10-Day Green Smoothie Cleanse11/22/63: A Novel...
# Author         JJ SmithStephen KingJordan B. PetersonGeorge O...
# User Rating                                               2540.1
# Reviews                                                  6574305
# Price                                                       7205
# Year                                                     1107700
# Genre          Non FictionFictionNon FictionFictionNon Fictio...
# dtype: object

# %%
bestsellers.rows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/jm/04h1_tp17ksdpkdy3qg7rtlh0000gn/T/ipykernel_92699/3903437913.py in ?()
# ----> 1 bestsellers.rows()
#
# ~/PycharmProjects/pythonProject/venv/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
bestsellers.describe(include="O")
# Out:
#                                                      Name       Author  \
# count                                                 550          550
# unique                                                351          248
# top     Publication Manual of the American Psychologic...  Jeff Kinney
# freq                                                   10           12
#
#               Genre
# count           550
# unique            2
# top     Non Fiction
# freq            310
